# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

page = requests.get('https://www.worldometers.info/coronavirus/')

html = BeautifulSoup(page.text, 'html.parser')
table = html.find('table', {'id': 'main_table_countries_today'})

tbody = table.find('tbody')

table_rows = tbody.find_all('tr')

data = []

for row in table_rows:
    row_data = []
    
    table_data = row.find_all('td')
    
    for i, td in enumerate(table_data):
        
            row_data.append(td.getText())
        
    data.append(row_data)
    print
    
df = pd.DataFrame(data)

# %%
cs = df.to_csv('worldometer.csv')

# %%
cs

# %%
df
# Out:
#        0                  1           2         3        4       5  \
# 0         \nNorth America\n  24,889,808  +209,938  534,030  +4,104
# 1                  \nAsia\n  21,140,900   +84,414  344,051  +1,058
# 2         \nSouth America\n  13,537,214   +60,557  368,940    +974
# 3                \nEurope\n  24,937,073  +265,860  569,930  +5,342
# 4                \nAfrica\n   2,903,318    +9,311   69,032    +182
# ..   ...                ...         ...       ...      ...     ...
# 223  216   Marshall Islands           4
# 224  217  Wallis and Futuna           4
# 225  218              Samoa           2
# 226  219            Vanuatu           1
# 227  220              China      87,215       +32   4,634
#
#               6         7           8       9   10 11           12       13  \
# 0    15,387,566  +116,364   8,968,212  35,696
# 1    19,648,119   +77,999   1,148,730  24,354
# 2    12,099,227    +2,832   1,069,047  18,183
# 3    13,383,398  +144,422  10,983,745  28,119
# 4     2,393,643    +6,829     440,643   2,368
# ..          ...       ...         ...     ...  ... ..          ...      ...
# 223           4                     0           67
# 224           1                     3          359           1,149  103,179
# 225           2                     0           10
# 226           1                     0            3
# 227      82,138       +21         443      14   61  3  160,000,000  111,163
#
#                  14                 15       16       17  18
# 0                        North America       \n
# 1                                 Asia       \n
# 2                        South America       \n
# 3                               Europe       \n
# 4                               Africa       \n
# ..              ...                ...      ...      ...  ..
# 223         59,396   Australia/Oceania   14,849
# 224         11,136   Australia/Oceania    2,784           10
# 225        199,093   Australia/Oceania   99,547
# 226        310,794   Australia/Oceania  310,794
# 227  1,439,323,776                Asia   16,503  310,601   9
#
# [228 rows x 19 columns]

# %%
t
